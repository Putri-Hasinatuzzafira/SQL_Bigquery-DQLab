# %% [markdown]
# <a href="https://colab.research.google.com/github/Putri-Hasinatuzzafira/SQL_Bigquery-DQLab/blob/main/01_select_limit_orderby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Pengantar</span></b>
#
# Dalam analisis data, langkah awal yang penting adalah mengambil, membatasi, dan mengurutkan informasi dari sumber data agar hasil yang diperoleh relevan dan mudah dipahami. Kemampuan untuk menampilkan data sesuai kebutuhan, hanya pada bagian yang diperlukan, serta menyusunnya dengan urutan yang tepat, menjadi dasar dalam proses eksplorasi dan pengolahan data. Dengan pemahaman konsep ini, seorang analis dapat bekerja lebih efisien dalam menemukan pola, menjawab pertanyaan bisnis, dan menyajikan insight yang akurat.

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Set up</span></b>
#
# Dibutuhkan proses autentikasi dari Google Colab ke Google Big Query. Ikuti langkah berikut https://drive.google.com/file/d/1gW8alZ_PrvcrsieqWCHOR4ssLI_25BRc/view untuk detail step-by-step nya

# %%
# Import library yang dibutuhkan
from google.colab import auth, data_table
from google.cloud import bigquery
from pandas_gbq import to_gbq

# Proses autentikasi akun
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# Buat BigQuery client
project_id = 'dqlab-putri512'
client = bigquery.Client(project = project_id)

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Latar Belakang</span></b>
#
# Di sebuah sudut kota Jakarta, telah didirikan sebuah restoran pizza bernama Plato’s Pizza. Selama satu tahun terakhir, telah dilakukan pencatatan atas setiap transaksi yang terjadi. Mulai dari pemesanan menu hingga pembayaran pelanggan. Banyak data telah dikumpulkan dan dicatat. Namun, belum dilakukan pemanfaatan optimal terhadap informasi yang tersedia. Pemilik restoran menginginkan agar data ini dapat dianalisis guna menemukan ruang untuk perbaikan dan melakukan efisiensi operasional sehingga diharapkan dapat meningkatkan penjualan pizza, menekan biaya operasional dan meningkatkan customer experience

# %% [markdown]
# <a id="A"></a>
# # <b>A. <span style='color:#0B2F9F'><code>SELECT</code></span></b>
#
# Perintah `SELECT` bertujuan untuk mengambil dan menampilkan data dari tabel di database. Ini penting untuk analisis karena saat menganalisa data perlu mengakses data yang relevan untuk dianalisis seperti mengidentifikasi pola, tren, dan informasi penting lainnya.

# %% [markdown]
# <a id="A.1."></a>
# ## <b>A.1. <span style='color:#0B2F9F'>Menampilkan Semua Data pada Satu Tabel</span></b>
#
# Untuk dapat menampilkan semua isi (data) pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select1.png" width="50%">
#
# Dalam perintah `SELECT`, tanda bintang (*) digunakan untuk memilih semua kolom dari tabel yang disebutkan. Cara ini merupakan cara cepat untuk mengambil seluruh data tanpa perlu menyebutkan nama-nama kolom satu per satu.
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/selecting-all.html">https://dev.mysql.com/doc/refman/8.4/en/selecting-all.html</a></i>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Management ingin mengetahui seluruh data transaksi pada DQPizza, sehingga tampilkan semua data pada tabel orders!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel orders
# SELECT * FROM dqlab-putri512.dq_pizza.orders
# LIMIT 50
# Out:
# Executing query with job ID: 30250943-0ca1-4552-a304-f81c716f0287
# Query executing: 0.76s
# Job ID 30250943-0ca1-4552-a304-f81c716f0287 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#      order_id customer_id order_maker_id  order_date order_time  \
# 0   TRX000026  CUST006333      EMP000208  01/01/2024   14:54:26
# 1   TRX000037  CUST003319      EMP000208  01/01/2024   16:56:09
# 2   TRX000057  CUST008422      EMP000208  01/01/2024   19:10:51
# 3   TRX000077  CUST001979      EMP000208  01/02/2024   12:22:46
# 4   TRX000087  CUST004837      EMP000208  01/02/2024   14:01:02
# 5   TRX000127  CUST008782      EMP000208  01/02/2024   20:58:23
# 6   TRX000133  CUST005109      EMP000208  01/02/2024   22:00:17
# 7   TRX000146  CUST007768      EMP000208  01/03/2024   14:22:10
# 8   TRX000155  CUST007931      EMP000208  01/03/2024   15:28:59
# 9   TRX000159  CUST005270      EMP000208  01/03/2024   15:59:22
# 10  TRX000173  CUST007150      EMP000208  01/03/2024   17:35:30
# 11  TRX000191  CUST003553      EMP000208  01/03/2024   20:24:50
# 12  TRX000199  CUST006964      EMP000208  01/03/2024   22:10:38
# 13  TRX000208  CUST009755      EMP000208  01/04/2024   12:12:05
# 14  TRX000213  CUST005584      EMP000208  01/04/2024   13:20:39
# 15  TRX000218  CUST008987      EMP000208  01/04/2024   14:35:11
# 16  TRX000260  CUST004841      EMP000208  01/05/2024   12:06:27
# 17  TRX000284  CUST001597      EMP000208  01/05/2024   16:58:16
# 18  TRX000294  CUST009381      EMP000208  01/05/2024   18:16:35
# 19  TRX000305  CUST009162      EMP000208  01/05/2024   20:35:40
# 20  TRX000337  CUST001128      EMP000208  01/06/2024   15:03:12
# 21  TRX000363  CUST007854      EMP000208  01/06/2024   19:20:31
# 22  TRX000387  CUST004307      EMP000208  01/07/2024   13:03:14
# 23  TRX000403  CUST002835      EMP000208  01/07/2024   16:26:10
# 24  TRX000410  CUST005584      EMP000208  01/07/2024   17:33:49
# 25  TRX000429  CUST005127      EMP000208  01/07/2024   22:16:53
# 26  TRX000433  CUST007254      EMP000208  01/08/2024   11:49:50
# 27  TRX000437  CUST001597      EMP000208  01/08/2024   12:07:54
# 28  TRX000451  CUST007482      EMP000208  01/08/2024   13:19:06
# 29  TRX000501  CUST008535      EMP000208  01/08/2024   21:51:31
# 30  TRX000502  CUST003147      EMP000208  01/08/2024   22:26:08
# 31  TRX000503  CUST008422      EMP000208  01/09/2024   11:16:21
# 32  TRX000504  CUST002287      EMP000208  01/09/2024   11:48:18
# 33  TRX000509  CUST004537      EMP000208  01/09/2024   12:13:58
# 34  TRX000519  CUST001042      EMP000208  01/09/2024   13:15:20
# 35  TRX000528  CUST002878      EMP000208  01/09/2024   15:27:21
# 36  TRX000546  CUST007656      EMP000208  01/09/2024   18:47:27
# 37  TRX000563  CUST005109      EMP000208  01/09/2024   22:19:03
# 38  TRX000569  CUST006043      EMP000208  01/10/2024   12:37:10
# 39  TRX000577  CUST008132      EMP000208  01/10/2024   13:45:00
# 40  TRX000613  CUST002998      EMP000208  01/10/2024   20:10:44
# 41  TRX000614  CUST002998      EMP000208  01/10/2024   20:12:33
# 42  TRX000643  CUST008674      EMP000208  01/11/2024   13:43:19
# 43  TRX000653  CUST001704      EMP000208  01/11/2024   16:18:23
# 44  TRX000655  CUST007562      EMP000208  01/11/2024   16:43:33
# 45  TRX000695  CUST006333      EMP000208  01/12/2024   13:33:06
# 46  TRX000699  CUST008535      EMP000208  01/12/2024   14:27:03
# 47  TRX000700  CUST007931      EMP000208  01/12/2024   14:31:13
# 48  TRX000729  CUST005264      EMP000208  01/12/2024   19:20:41
# 49  TRX000734  CUST003549      EMP000208  01/12/2024   20:00:30
#
#    completion_time  is_complain complain_detail
# 0         15:23:02            0            None
# 1         17:18:48            0            None
# 2         19:30:38            0            None
# 3         12:41:29            0            None
# 4         14:29:46            0            None
# 5         21:16:43            0            None
# 6         22:16:50            0            None
# 7         14:44:44            0            None
# 8         15:48:33            0            None
# 9         16:16:07            0            None
# 10        17:57:32            0            None
# 11        20:35:48            0            None
# 12        22:36:06            0            None
# 13        12:41:56            0            None
# 14        13:50:02            0            None
# 15        14:54:53            0            None
# 16        12:22:51            0            None
# 17        17:25:57            0            None
# 18        18:31:04            0            None
# 19        21:00:59            0            None
# 20        15:14:12            0            None
# 21        19:42:15            0            None
# 22        13:31:16            0            None
# 23        16:53:02            0            None
# 24        18:02:45            0            None
# 25        22:28:31            0            None
# 26        12:07:28            0            None
# 27        12:24:37            0            None
# 28        13:40:31            0            None
# 29        22:11:57            0            None
# 30        22:44:56            0            None
# 31        11:31:43            0            None
# 32        12:13:30            0            None
# 33        12:31:15            0            None
# 34        13:26:34            0            None
# 35        15:54:22            0            None
# 36        19:12:41            0            None
# 37        22:34:20            0            None
# 38        12:52:57            0            None
# 39        13:56:29            0            None
# 40        20:28:36            0            None
# 41        20:23:25            0            None
# 42        14:06:24            0            None
# 43        16:47:47            0            None
# 44        16:56:37            0            None
# 45        13:57:15            0            None
# 46        14:47:50            0            None
# 47        14:41:35            0            None
# 48        19:33:07            0            None
# 49        20:27:49            0            None

# %% [markdown]
# <a id="A.2."></a>
# ## <b>A.2. <span style='color:#0B2F9F'>Menampilkan Kolom Tertentu pada Satu Tabel</span></b>
#
# Untuk dapat menampilkan isi data pada kolom tertentu pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select2.png" width="50%">
#
# Gunakan tanda koma untuk mendaftarkan nama kolom yang ingin ditampilkan. Kolom yang disebutkan pertama kali akan ditampilkan paling kiri begitu juga dengan kolom kedua hingga kolom terakhir.
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/selecting-columns.html">https://dev.mysql.com/doc/refman/8.4/en/selecting-columns.html</a></i>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom order_id, customer_id dan order_date pada tabel orders!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan kolom order_id, customer_id dan order_date pada tabel orders
# SELECT order_id, customer_id, order_date FROM dqlab-putri512.dq_pizza.orders
# LIMIT 50
# Out:
# Executing query with job ID: a6ae3400-397e-43e4-9005-e4cb8f21711f
# Query executing: 0.50s
# Job ID a6ae3400-397e-43e4-9005-e4cb8f21711f successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#      order_id customer_id  order_date
# 0   TRX000026  CUST006333  01/01/2024
# 1   TRX000037  CUST003319  01/01/2024
# 2   TRX000057  CUST008422  01/01/2024
# 3   TRX000077  CUST001979  01/02/2024
# 4   TRX000087  CUST004837  01/02/2024
# 5   TRX000127  CUST008782  01/02/2024
# 6   TRX000133  CUST005109  01/02/2024
# 7   TRX000146  CUST007768  01/03/2024
# 8   TRX000155  CUST007931  01/03/2024
# 9   TRX000159  CUST005270  01/03/2024
# 10  TRX000173  CUST007150  01/03/2024
# 11  TRX000191  CUST003553  01/03/2024
# 12  TRX000199  CUST006964  01/03/2024
# 13  TRX000208  CUST009755  01/04/2024
# 14  TRX000213  CUST005584  01/04/2024
# 15  TRX000218  CUST008987  01/04/2024
# 16  TRX000260  CUST004841  01/05/2024
# 17  TRX000284  CUST001597  01/05/2024
# 18  TRX000294  CUST009381  01/05/2024
# 19  TRX000305  CUST009162  01/05/2024
# 20  TRX000337  CUST001128  01/06/2024
# 21  TRX000363  CUST007854  01/06/2024
# 22  TRX000387  CUST004307  01/07/2024
# 23  TRX000403  CUST002835  01/07/2024
# 24  TRX000410  CUST005584  01/07/2024
# 25  TRX000429  CUST005127  01/07/2024
# 26  TRX000433  CUST007254  01/08/2024
# 27  TRX000437  CUST001597  01/08/2024
# 28  TRX000451  CUST007482  01/08/2024
# 29  TRX000501  CUST008535  01/08/2024
# 30  TRX000502  CUST003147  01/08/2024
# 31  TRX000503  CUST008422  01/09/2024
# 32  TRX000504  CUST002287  01/09/2024
# 33  TRX000509  CUST004537  01/09/2024
# 34  TRX000519  CUST001042  01/09/2024
# 35  TRX000528  CUST002878  01/09/2024
# 36  TRX000546  CUST007656  01/09/2024
# 37  TRX000563  CUST005109  01/09/2024
# 38  TRX000569  CUST006043  01/10/2024
# 39  TRX000577  CUST008132  01/10/2024
# 40  TRX000613  CUST002998  01/10/2024
# 41  TRX000614  CUST002998  01/10/2024
# 42  TRX000643  CUST008674  01/11/2024
# 43  TRX000653  CUST001704  01/11/2024
# 44  TRX000655  CUST007562  01/11/2024
# 45  TRX000695  CUST006333  01/12/2024
# 46  TRX000699  CUST008535  01/12/2024
# 47  TRX000700  CUST007931  01/12/2024
# 48  TRX000729  CUST005264  01/12/2024
# 49  TRX000734  CUST003549  01/12/2024

# %% [markdown]
# <a id="A.3."></a>
# ## <b>A.3. <span style='color:#0B2F9F'>Mengubah Penyebutan Nama Kolom pada Satu Tabel</span></b>
#
# Terkadang perlu untuk memberi nama lain pada saat data ditampilkan untuk mempermudah pembacaan atau tujuan lainnya. Untuk mengubah nama sementara yang diberikan kepada kolom atau tabel dalam query bisa menggunakan perintah `AS` atau biasa disebut Alias. Untuk dapat mengubah nama kolom sementara pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select3.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom order_id, customer_id, order_date dan is_complain pada tabel orders namun ubah penamaan is_complain pada output menjadi is_customer_complain agar lebih jelas</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan kolom order_id, customer_id, order_date dan is_complain pada tabel orders
# -- namun ubah penamaan is_complain pada output menjadi is_customer_complain
# SELECT
#   order_id,
#   customer_id,
#   order_date,
#   is_complain AS is_customer_complain
# FROM dqlab-putri512.dq_pizza.orders
# LIMIT 50
# Out:
# Executing query with job ID: 946227e4-18ba-4ad9-a1a0-562561c1723b
# Query executing: 0.55s
# Job ID 946227e4-18ba-4ad9-a1a0-562561c1723b successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#      order_id customer_id  order_date  is_customer_complain
# 0   TRX000026  CUST006333  01/01/2024                     0
# 1   TRX000037  CUST003319  01/01/2024                     0
# 2   TRX000057  CUST008422  01/01/2024                     0
# 3   TRX000077  CUST001979  01/02/2024                     0
# 4   TRX000087  CUST004837  01/02/2024                     0
# 5   TRX000127  CUST008782  01/02/2024                     0
# 6   TRX000133  CUST005109  01/02/2024                     0
# 7   TRX000146  CUST007768  01/03/2024                     0
# 8   TRX000155  CUST007931  01/03/2024                     0
# 9   TRX000159  CUST005270  01/03/2024                     0
# 10  TRX000173  CUST007150  01/03/2024                     0
# 11  TRX000191  CUST003553  01/03/2024                     0
# 12  TRX000199  CUST006964  01/03/2024                     0
# 13  TRX000208  CUST009755  01/04/2024                     0
# 14  TRX000213  CUST005584  01/04/2024                     0
# 15  TRX000218  CUST008987  01/04/2024                     0
# 16  TRX000260  CUST004841  01/05/2024                     0
# 17  TRX000284  CUST001597  01/05/2024                     0
# 18  TRX000294  CUST009381  01/05/2024                     0
# 19  TRX000305  CUST009162  01/05/2024                     0
# 20  TRX000337  CUST001128  01/06/2024                     0
# 21  TRX000363  CUST007854  01/06/2024                     0
# 22  TRX000387  CUST004307  01/07/2024                     0
# 23  TRX000403  CUST002835  01/07/2024                     0
# 24  TRX000410  CUST005584  01/07/2024                     0
# 25  TRX000429  CUST005127  01/07/2024                     0
# 26  TRX000433  CUST007254  01/08/2024                     0
# 27  TRX000437  CUST001597  01/08/2024                     0
# 28  TRX000451  CUST007482  01/08/2024                     0
# 29  TRX000501  CUST008535  01/08/2024                     0
# 30  TRX000502  CUST003147  01/08/2024                     0
# 31  TRX000503  CUST008422  01/09/2024                     0
# 32  TRX000504  CUST002287  01/09/2024                     0
# 33  TRX000509  CUST004537  01/09/2024                     0
# 34  TRX000519  CUST001042  01/09/2024                     0
# 35  TRX000528  CUST002878  01/09/2024                     0
# 36  TRX000546  CUST007656  01/09/2024                     0
# 37  TRX000563  CUST005109  01/09/2024                     0
# 38  TRX000569  CUST006043  01/10/2024                     0
# 39  TRX000577  CUST008132  01/10/2024                     0
# 40  TRX000613  CUST002998  01/10/2024                     0
# 41  TRX000614  CUST002998  01/10/2024                     0
# 42  TRX000643  CUST008674  01/11/2024                     0
# 43  TRX000653  CUST001704  01/11/2024                     0
# 44  TRX000655  CUST007562  01/11/2024                     0
# 45  TRX000695  CUST006333  01/12/2024                     0
# 46  TRX000699  CUST008535  01/12/2024                     0
# 47  TRX000700  CUST007931  01/12/2024                     0
# 48  TRX000729  CUST005264  01/12/2024                     0
# 49  TRX000734  CUST003549  01/12/2024                     0

# %% [markdown]
# <a id="B"></a>
# # <b>B. <span style='color:#E1B12D'><code>DISTINCT</code></span></b>
#
# Perintah `DISTINCT` dalam SQL digunakan untuk menghapus duplikasi dalam hasil query. Dengan `DISTINCT`, dapat dipastikan bahwa setiap baris dalam hasil query unik dan tidak ada baris yang sama. Untuk menggunakan perintah ini haruslah diletakkan setelah perintah `SELECT`.
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Distinct.png" width="50%">
#
# docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/distinct-optimization.html"><i>https://dev.mysql.com/doc/refman/8.4/en/distinct-optimization.html</a></i>

# %% [markdown]
# <a id="B.1."></a>
# ## <b>B.1. <span style='color:#0B2F9F'>Nilai Unik pada Satu Kolom Tertentu</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Beberapa kali DQPizza mengalami komplain, sebutkan apa saja komplain yang pernah terjadi di DQPizza!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan komplain apa saja yang pernah terjadi di DQPizza
# SELECT DISTINCT complain_detail FROM dqlab-putri512.dq_pizza.orders
# LIMIT 50
# Out:
# Executing query with job ID: 0860e0c4-b3a7-4e5d-b310-264e40f03422
# Query executing: 0.40s
# Job ID 0860e0c4-b3a7-4e5d-b310-264e40f03422 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#          complain_detail
# 0                   None
# 1      Dough undercooked
# 2      Drink was missing
# 3       Missing toppings
# 4    Order took too long
# 5        Pizza was burnt
# 6   Received wrong pizza
# 7  Rude staff at counter
# 8       Wrong pizza size

# %% [markdown]
# <a id="B.2."></a>
# ## <b>B.2. <span style='color:#0B2F9F'>Nilai Unik pada Lebih dari Satu Kolom</span></b>
#
# Perintah `DISTINCT` dapat diterapkan dilebih dari satu kolom. Jika diterapkan pada lebih dari satu kolom maka akan menghasilkan kombinasi unik antar baris pada kolom yang terpilih

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan siapa saja karyawan yang pernah menerima komplain dan
# -- jenis komplain apa saja yang pernah terjadi di DQPizza
# SELECT DISTINCT
#   order_maker_id,
#   complain_detail
# FROM dqlab-putri512.dq_pizza.orders
# LIMIT 50
# Out:
# Executing query with job ID: f5006b9d-fb46-4188-8634-1595fe8d4325
# Query executing: 0.49s
# Job ID f5006b9d-fb46-4188-8634-1595fe8d4325 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#    order_maker_id      complain_detail
# 0       EMP000208                 None
# 1       EMP000231                 None
# 2       EMP000286                 None
# 3       EMP000295                 None
# 4       EMP000302                 None
# 5       EMP000437                 None
# 6       EMP000560                 None
# 7       EMP000646                 None
# 8       EMP000665                 None
# 9       EMP000756                 None
# 10      EMP000208    Dough undercooked
# 11      EMP000231    Dough undercooked
# 12      EMP000286    Dough undercooked
# 13      EMP000295    Dough undercooked
# 14      EMP000302    Dough undercooked
# 15      EMP000437    Dough undercooked
# 16      EMP000560    Dough undercooked
# 17      EMP000646    Dough undercooked
# 18      EMP000665    Dough undercooked
# 19      EMP000756    Dough undercooked
# 20      EMP000208    Drink was missing
# 21      EMP000231    Drink was missing
# 22      EMP000286    Drink was missing
# 23      EMP000295    Drink was missing
# 24      EMP000302    Drink was missing
# 25      EMP000437    Drink was missing
# 26      EMP000560    Drink was missing
# 27      EMP000646    Drink was missing
# 28      EMP000665    Drink was missing
# 29      EMP000756    Drink was missing
# 30      EMP000208     Missing toppings
# 31      EMP000231     Missing toppings
# 32      EMP000286     Missing toppings
# 33      EMP000295     Missing toppings
# 34      EMP000302     Missing toppings
# 35      EMP000437     Missing toppings
# 36      EMP000560     Missing toppings
# 37      EMP000646     Missing toppings
# 38      EMP000665     Missing toppings
# 39      EMP000756     Missing toppings
# 40      EMP000208  Order took too long
# 41      EMP000231  Order took too long
# 42      EMP000286  Order took too long
# 43      EMP000295  Order took too long
# 44      EMP000302  Order took too long
# 45      EMP000437  Order took too long
# 46      EMP000560  Order took too long
# 47      EMP000646  Order took too long
# 48      EMP000665  Order took too long
# 49      EMP000756  Order took too long

# %% [markdown]
# <a id="C"></a>
# # <b>C. <span style='color:#E1B12D'><code>LIMIT</code></span></b>
#
# Tidak semua data ingin ditampilkan untuk proses <i>sampling</i>, sehingga perlu dikontrol dan melakukan pembatasan jumlah baris yang dikembalikan oleh sebuah query.
# Perintah `LIMIT <jumlah_data>` dalam SQL digunakan untuk membatasi data yang ingin ditampilkan. `LIMIT` diletakkan paling akhir dari sebuah query dengan perintah `SELECT`.
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Limit.png" width="50%">
#
# docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/limit-optimization.html"><i>https://dev.mysql.com/doc/refman/8.4/en/limit-optimization.html</a></i>

# %% [markdown]
# <a id="C.1."></a>
# ## <b>C.1. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Semua Kolom pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua 5 data teratas pada tabel orders!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua 5 data pada tabel orders
# SELECT * FROM dqlab-putri512.dq_pizza.orders
# LIMIT 5
# Out:
# Executing query with job ID: af8849f1-0a3a-49ef-a17b-fc298c2b9917
# Query executing: 0.47s
# Job ID af8849f1-0a3a-49ef-a17b-fc298c2b9917 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id order_maker_id  order_date order_time  \
# 0  TRX000026  CUST006333      EMP000208  01/01/2024   14:54:26
# 1  TRX000037  CUST003319      EMP000208  01/01/2024   16:56:09
# 2  TRX000057  CUST008422      EMP000208  01/01/2024   19:10:51
# 3  TRX000077  CUST001979      EMP000208  01/02/2024   12:22:46
# 4  TRX000087  CUST004837      EMP000208  01/02/2024   14:01:02
#
#   completion_time  is_complain complain_detail
# 0        15:23:02            0            None
# 1        17:18:48            0            None
# 2        19:30:38            0            None
# 3        12:41:29            0            None
# 4        14:29:46            0            None

# %% [markdown]
# <a id="C.2."></a>
# ## <b>C.2. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Kolom Tertentu pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 7 data teratas untuk kolom order_id, customer_id, dan order_date pada tabel orders!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan 7 data teratas saja untuk kolom order_id, customer_id dan order_date
# SELECT
#   order_id,
#   customer_id,
#   order_date
# FROM dqlab-putri512.dq_pizza.orders
# LIMIT 7
# Out:
# Executing query with job ID: 8594c5d0-e789-4e41-8d7a-b8fe683674d7
# Query executing: 0.39s
# Job ID 8594c5d0-e789-4e41-8d7a-b8fe683674d7 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id  order_date
# 0  TRX000026  CUST006333  01/01/2024
# 1  TRX000037  CUST003319  01/01/2024
# 2  TRX000057  CUST008422  01/01/2024
# 3  TRX000077  CUST001979  01/02/2024
# 4  TRX000087  CUST004837  01/02/2024
# 5  TRX000127  CUST008782  01/02/2024
# 6  TRX000133  CUST005109  01/02/2024

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 5 data saja pada kolom order_id, customer_id, order_date dan is_complain pada tabel orders namun ubah penamaan is_complain pada output menjadi is_customer_complain agar lebih jelas</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan 5 data teratas saja untuk kolom order_id, customer_id, order_date dan is_complain pada tabel orders
# -- namun ubah penamaan is_complain pada output menjadi is_customer_complain
# SELECT
#   order_id,
#   customer_id,
#   order_date,
#   is_complain AS is_customer_complain
# FROM dqlab-putri512.dq_pizza.orders
# LIMIT 5
# Out:
# Executing query with job ID: 16ed2618-69d8-431d-8ab0-4f00937de387
# Query executing: 0.43s
# Job ID 16ed2618-69d8-431d-8ab0-4f00937de387 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id  order_date  is_customer_complain
# 0  TRX000026  CUST006333  01/01/2024                     0
# 1  TRX000037  CUST003319  01/01/2024                     0
# 2  TRX000057  CUST008422  01/01/2024                     0
# 3  TRX000077  CUST001979  01/02/2024                     0
# 4  TRX000087  CUST004837  01/02/2024                     0

# %% [markdown]
# <a id="D"></a>
# # <b>D. <span style='color:#E1B12D'><code>ORDER BY</code></span></b>
#
# Perintah lain yang tak kalah penting yang membantu dalam menganalisis data untuk melihat data dalam urutan yang diinginkan adalah perintah `ORDER BY`. Perintah `ORDER BY` dalam SQL digunakan untuk mengurutkan hasil query berdasarkan satu atau lebih kolom. Cara pengurutan data dibagi menjadi dua cara yakni <b>Ascending</b> dan <b>Descending</b>
# <ul>
#     <li><b>Ascending</b> : Pengurutan secara naik (dari kecil ke besar) atau A-Z</li>
#     <li><b>Descending</b> : Pengurutan secara turun (dari besar ke kecil) atau Z-A</li>
# </ul>
#
# Untuk dapat menampilkan isi data secara terurut pada kolom tertentu pada sebuah tabel, eksekusi perintah
#
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/sorting-rows.html">https://dev.mysql.com/doc/refman/8.4/en/sorting-rows.html</a></i>

# %% [markdown]
# <a id="D.1."></a>
# ## <b>D.1. <span style='color:#0B2F9F'>Mengurutkan secara <i>Ascending</i></span></b>
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-OrderByASC.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel orders namun urutkan berdasarkan kolom order_id secara ascending!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel orders terurut berdasarkan kolom order_id secara ascending
# SELECT * FROM dqlab-putri512.dq_pizza.orders
# ORDER BY order_id ASC
# LIMIT 50
# Out:
# Executing query with job ID: cfc83837-bd1f-4d71-96cf-798215ad641c
# Query executing: 0.43s
# Job ID cfc83837-bd1f-4d71-96cf-798215ad641c successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#      order_id customer_id order_maker_id  order_date order_time  \
# 0   TRX000001  CUST007150      EMP000286  01/01/2024   11:38:36
# 1   TRX000002  CUST003319      EMP000646  01/01/2024   11:57:40
# 2   TRX000003  CUST001979      EMP000437  01/01/2024   12:12:28
# 3   TRX000004  CUST007254      EMP000302  01/01/2024   12:16:31
# 4   TRX000005  CUST004392      EMP000231  01/01/2024   12:21:30
# 5   TRX000006  CUST002637      EMP000437  01/01/2024   12:29:36
# 6   TRX000007  CUST001120      EMP000302  01/01/2024   12:50:37
# 7   TRX000008  CUST008782      EMP000286  01/01/2024   12:51:37
# 8   TRX000009  CUST005127      EMP000295  01/01/2024   12:52:01
# 9   TRX000010  CUST007931      EMP000437  01/01/2024   13:00:15
# 10  TRX000011  CUST004105      EMP000231  01/01/2024   13:02:59
# 11  TRX000012  CUST007482      EMP000560  01/01/2024   13:04:41
# 12  TRX000013  CUST004504      EMP000231  01/01/2024   13:11:55
# 13  TRX000014  CUST001597      EMP000302  01/01/2024   13:14:19
# 14  TRX000015  CUST001128      EMP000286  01/01/2024   13:33:00
# 15  TRX000016  CUST005109      EMP000560  01/01/2024   13:34:07
# 16  TRX000017  CUST002583      EMP000665  01/01/2024   13:53:00
# 17  TRX000018  CUST001597      EMP000437  01/01/2024   13:57:08
# 18  TRX000019  CUST001704      EMP000295  01/01/2024   13:59:09
# 19  TRX000020  CUST001704      EMP000560  01/01/2024   14:03:08
# 20  TRX000021  CUST004778      EMP000437  01/01/2024   14:14:29
# 21  TRX000022  CUST006034      EMP000756  01/01/2024   14:16:26
# 22  TRX000023  CUST006814      EMP000286  01/01/2024   14:19:03
# 23  TRX000024  CUST009381      EMP000437  01/01/2024   14:23:01
# 24  TRX000025  CUST001704      EMP000437  01/01/2024   14:44:44
# 25  TRX000026  CUST006333      EMP000208  01/01/2024   14:54:26
# 26  TRX000027  CUST004945      EMP000665  01/01/2024   15:11:17
# 27  TRX000028  CUST006964      EMP000560  01/01/2024   15:35:46
# 28  TRX000029  CUST006964      EMP000646  01/01/2024   15:41:01
# 29  TRX000030  CUST009162      EMP000286  01/01/2024   15:41:25
# 30  TRX000031  CUST003147      EMP000756  01/01/2024   15:50:18
# 31  TRX000032  CUST001704      EMP000756  01/01/2024   15:53:18
# 32  TRX000033  CUST004817      EMP000437  01/01/2024   15:54:08
# 33  TRX000034  CUST008535      EMP000231  01/01/2024   16:21:21
# 34  TRX000035  CUST008674      EMP000646  01/01/2024   16:32:04
# 35  TRX000036  CUST003319      EMP000560  01/01/2024   16:54:09
# 36  TRX000037  CUST003319      EMP000208  01/01/2024   16:56:09
# 37  TRX000038  CUST008422      EMP000286  01/01/2024   17:03:00
# 38  TRX000039  CUST009162      EMP000295  01/01/2024   17:07:23
# 39  TRX000040  CUST003553      EMP000665  01/01/2024   17:14:36
# 40  TRX000041  CUST007809      EMP000437  01/01/2024   17:15:20
# 41  TRX000042  CUST008987      EMP000231  01/01/2024   17:28:09
# 42  TRX000043  CUST003228      EMP000231  01/01/2024   17:38:34
# 43  TRX000044  CUST003553      EMP000437  01/01/2024   17:54:20
# 44  TRX000045  CUST001704      EMP000665  01/01/2024   17:55:48
# 45  TRX000046  CUST007656      EMP000295  01/01/2024   18:25:51
# 46  TRX000047  CUST004392      EMP000665  01/01/2024   18:26:34
# 47  TRX000048  CUST007854      EMP000665  01/01/2024   18:26:42
# 48  TRX000049  CUST005956      EMP000286  01/01/2024   18:33:00
# 49  TRX000050  CUST004778      EMP000295  01/01/2024   18:41:01
#
#    completion_time  is_complain    complain_detail
# 0         12:03:29            0               None
# 1         12:09:32            0               None
# 2         12:38:02            1   Missing toppings
# 3         12:32:46            1   Missing toppings
# 4         12:33:05            0               None
# 5         12:51:58            0               None
# 6         13:05:46            0               None
# 7         13:10:27            0               None
# 8         13:09:05            0               None
# 9         13:14:11            0               None
# 10        13:27:56            0               None
# 11        13:19:20            0               None
# 12        13:25:24            0               None
# 13        13:40:56            0               None
# 14        13:53:31            0               None
# 15        14:01:20            0               None
# 16        14:06:11            1   Wrong pizza size
# 17        14:24:26            0               None
# 18        14:15:45            0               None
# 19        14:18:24            1   Missing toppings
# 20        14:31:46            0               None
# 21        14:31:00            0               None
# 22        14:46:44            0               None
# 23        14:49:19            0               None
# 24        15:04:20            0               None
# 25        15:23:02            0               None
# 26        15:39:35            0               None
# 27        15:52:26            0               None
# 28        15:58:12            1    Pizza was burnt
# 29        16:06:24            0               None
# 30        16:06:50            0               None
# 31        16:16:43            0               None
# 32        16:10:33            0               None
# 33        16:39:18            0               None
# 34        16:48:09            1  Dough undercooked
# 35        17:04:30            0               None
# 36        17:18:48            0               None
# 37        17:15:19            0               None
# 38        17:19:07            0               None
# 39        17:40:21            0               None
# 40        17:35:32            0               None
# 41        17:39:06            0               None
# 42        17:50:25            0               None
# 43        18:19:26            0               None
# 44        18:14:33            0               None
# 45        18:40:07            0               None
# 46        18:54:14            0               None
# 47        18:49:48            0               None
# 48        18:44:49            0               None
# 49        19:03:34            1    Pizza was burnt

# %% [markdown]
# <a id="D.2."></a>
# ## <b>D.2. <span style='color:#0B2F9F'>Mengurutkan secara <i>Descending</i></span></b>
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-OrderByDESC.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel orders namun urutkan berdasarkan kolom order_date secara descending!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel orders terurut berdasarkan kolom order_date secara descending
# SELECT * FROM dqlab-putri512.dq_pizza.orders
# ORDER BY order_date DESC
# LIMIT 50
# Out:
# Executing query with job ID: aa36cce9-ae0e-455b-95b1-adb62fdc2ab8
# Query executing: 0.55s
# Job ID aa36cce9-ae0e-455b-95b1-adb62fdc2ab8 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#      order_id customer_id order_maker_id  order_date order_time  \
# 0   TRX021340  CUST005584      EMP000302  12/31/2024   19:51:52
# 1   TRX021343  CUST009740      EMP000208  12/31/2024   20:27:23
# 2   TRX021347  CUST003549      EMP000302  12/31/2024   21:14:37
# 3   TRX021299  CUST003570      EMP000295  12/31/2024   15:52:16
# 4   TRX021312  CUST008578      EMP000208  12/31/2024   17:21:24
# 5   TRX021285  CUST006043      EMP000295  12/31/2024   12:41:37
# 6   TRX021311  CUST006034      EMP000231  12/31/2024   17:17:26
# 7   TRX021346  CUST005584      EMP000560  12/31/2024   20:51:07
# 8   TRX021282  CUST007854      EMP000286  12/31/2024   12:09:59
# 9   TRX021339  CUST007150      EMP000302  12/31/2024   19:46:24
# 10  TRX021333  CUST005956      EMP000295  12/31/2024   19:16:54
# 11  TRX021308  CUST008132      EMP000286  12/31/2024   16:44:35
# 12  TRX021293  CUST004212      EMP000231  12/31/2024   14:40:24
# 13  TRX021283  CUST006964      EMP000437  12/31/2024   12:14:54
# 14  TRX021287  CUST004609      EMP000302  12/31/2024   12:48:36
# 15  TRX021324  CUST002945      EMP000208  12/31/2024   18:36:06
# 16  TRX021280  CUST005270      EMP000295  12/31/2024   11:58:28
# 17  TRX021315  CUST003570      EMP000231  12/31/2024   17:47:46
# 18  TRX021279  CUST008674      EMP000646  12/31/2024   11:38:45
# 19  TRX021344  CUST004170      EMP000560  12/31/2024   20:43:46
# 20  TRX021336  CUST003319      EMP000295  12/31/2024   19:19:26
# 21  TRX021301  CUST003228      EMP000286  12/31/2024   16:01:07
# 22  TRX021349  CUST004212      EMP000231  12/31/2024   22:09:54
# 23  TRX021334  CUST005264      EMP000295  12/31/2024   19:17:49
# 24  TRX021296  CUST004293      EMP000295  12/31/2024   15:13:40
# 25  TRX021318  CUST006034      EMP000295  12/31/2024   18:07:03
# 26  TRX021337  CUST008535      EMP000231  12/31/2024   19:22:31
# 27  TRX021289  CUST001128      EMP000295  12/31/2024   13:07:42
# 28  TRX021321  CUST008422      EMP000286  12/31/2024   18:18:30
# 29  TRX021319  CUST005205      EMP000437  12/31/2024   18:07:19
# 30  TRX021306  CUST004293      EMP000208  12/31/2024   16:31:27
# 31  TRX021317  CUST002637      EMP000437  12/31/2024   18:01:42
# 32  TRX021284  CUST007931      EMP000437  12/31/2024   12:34:06
# 33  TRX021294  CUST006843      EMP000560  12/31/2024   14:43:46
# 34  TRX021298  CUST005429      EMP000231  12/31/2024   15:35:37
# 35  TRX021313  CUST008004      EMP000286  12/31/2024   17:22:08
# 36  TRX021328  CUST007854      EMP000231  12/31/2024   18:46:11
# 37  TRX021290  CUST009162      EMP000560  12/31/2024   13:16:45
# 38  TRX021322  CUST004105      EMP000231  12/31/2024   18:28:04
# 39  TRX021286  CUST005127      EMP000560  12/31/2024   12:44:37
# 40  TRX021278  CUST007482      EMP000302  12/31/2024   11:22:31
# 41  TRX021281  CUST005109      EMP000646  12/31/2024   12:01:03
# 42  TRX021291  CUST007150      EMP000286  12/31/2024   13:29:39
# 43  TRX021303  CUST005584      EMP000646  12/31/2024   16:30:34
# 44  TRX021288  CUST004105      EMP000646  12/31/2024   13:04:18
# 45  TRX021302  CUST004841      EMP000560  12/31/2024   16:06:42
# 46  TRX021348  CUST007931      EMP000437  12/31/2024   21:23:10
# 47  TRX021326  CUST007747      EMP000302  12/31/2024   18:38:38
# 48  TRX021295  CUST004837      EMP000295  12/31/2024   14:52:25
# 49  TRX021297  CUST009740      EMP000231  12/31/2024   15:28:07
#
#    completion_time  is_complain complain_detail
# 0         20:09:09            0            None
# 1         20:46:24            0            None
# 2         21:30:28            0            None
# 3         16:09:32            0            None
# 4         17:33:10            0            None
# 5         13:09:44            0            None
# 6         17:40:16            0            None
# 7         21:20:56            0            None
# 8         12:24:40            0            None
# 9         20:04:36            0            None
# 10        19:29:11            0            None
# 11        17:14:09            0            None
# 12        15:03:47            0            None
# 13        12:26:53            0            None
# 14        13:00:58            0            None
# 15        18:51:40            0            None
# 16        12:18:29            0            None
# 17        18:04:15            0            None
# 18        11:58:06            0            None
# 19        21:01:44            0            None
# 20        19:40:50            0            None
# 21        16:16:47            0            None
# 22        22:29:02            0            None
# 23        19:33:17            0            None
# 24        15:24:05            0            None
# 25        18:33:46            0            None
# 26        19:49:45            0            None
# 27        13:29:25            0            None
# 28        18:40:54            0            None
# 29        18:30:42            0            None
# 30        16:43:31            0            None
# 31        18:13:15            0            None
# 32        12:56:43            0            None
# 33        15:06:29            0            None
# 34        15:58:18            0            None
# 35        17:34:07            0            None
# 36        19:03:22            0            None
# 37        13:32:27            0            None
# 38        18:38:37            0            None
# 39        13:05:05            0            None
# 40        11:33:28            0            None
# 41        12:18:58            0            None
# 42        13:40:59            0            None
# 43        16:56:06            0            None
# 44        13:30:22            0            None
# 45        16:20:57            0            None
# 46        21:47:34            0            None
# 47        18:57:58            0            None
# 48        15:04:44            0            None
# 49        15:50:36            0            None

# %% [markdown]
# <a id="D.3."></a>
# ## <b>D.3. <span style='color:#0B2F9F'>Kombinasi <i>Ascending</i> & <i>Descending</i> saat Mengurutkan Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi, urutkan berdasarkan jenis komplainnya secara descending dan kode pegawai secara ascending!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi
# -- urutkan berdasarkan jenis komplainnya secara descending dan kode pegawai secara ascending
# SELECT DISTINCT
# order_maker_id,
# complain_detail
# FROM dqlab-putri512.dq_pizza.orders
# ORDER BY
# complain_detail DESC,
# order_maker_id ASC
# LIMIT 50
# Out:
# Executing query with job ID: eaef8311-b408-4a1d-83d5-a4c8054551d3
# Query executing: 0.52s
# Job ID eaef8311-b408-4a1d-83d5-a4c8054551d3 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#    order_maker_id        complain_detail
# 0       EMP000208       Wrong pizza size
# 1       EMP000231       Wrong pizza size
# 2       EMP000286       Wrong pizza size
# 3       EMP000295       Wrong pizza size
# 4       EMP000302       Wrong pizza size
# 5       EMP000437       Wrong pizza size
# 6       EMP000560       Wrong pizza size
# 7       EMP000646       Wrong pizza size
# 8       EMP000665       Wrong pizza size
# 9       EMP000756       Wrong pizza size
# 10      EMP000208  Rude staff at counter
# 11      EMP000231  Rude staff at counter
# 12      EMP000286  Rude staff at counter
# 13      EMP000295  Rude staff at counter
# 14      EMP000302  Rude staff at counter
# 15      EMP000437  Rude staff at counter
# 16      EMP000560  Rude staff at counter
# 17      EMP000646  Rude staff at counter
# 18      EMP000665  Rude staff at counter
# 19      EMP000756  Rude staff at counter
# 20      EMP000208   Received wrong pizza
# 21      EMP000231   Received wrong pizza
# 22      EMP000286   Received wrong pizza
# 23      EMP000295   Received wrong pizza
# 24      EMP000302   Received wrong pizza
# 25      EMP000437   Received wrong pizza
# 26      EMP000560   Received wrong pizza
# 27      EMP000646   Received wrong pizza
# 28      EMP000665   Received wrong pizza
# 29      EMP000756   Received wrong pizza
# 30      EMP000208        Pizza was burnt
# 31      EMP000231        Pizza was burnt
# 32      EMP000286        Pizza was burnt
# 33      EMP000295        Pizza was burnt
# 34      EMP000302        Pizza was burnt
# 35      EMP000437        Pizza was burnt
# 36      EMP000560        Pizza was burnt
# 37      EMP000646        Pizza was burnt
# 38      EMP000665        Pizza was burnt
# 39      EMP000756        Pizza was burnt
# 40      EMP000208    Order took too long
# 41      EMP000231    Order took too long
# 42      EMP000286    Order took too long
# 43      EMP000295    Order took too long
# 44      EMP000302    Order took too long
# 45      EMP000437    Order took too long
# 46      EMP000560    Order took too long
# 47      EMP000646    Order took too long
# 48      EMP000665    Order took too long
# 49      EMP000756    Order took too long

# %% [markdown]
# Data Source : <i>https://mavenanalytics.io/challenges/maven-pizza-challenge</i> (dengan modifikasi)
#
#
# ---
#
# <br>
# <a href="https://www.linkedin.com/in/putri-hasinatuzzafira/"><img src="https://img.shields.io/badge/-© 2025 Putri Hasinatuzzafira-417DAC?style=for-the-badge&logoColor=white"/></a>
#
# <a href="https://dqlab.id/"><img src="https://dqlab.id/files/dqlab/cache/87e30118ebba5ec7d96f6ea8c9dcc10b_x_118_X_55.png" align="left" /></a>
